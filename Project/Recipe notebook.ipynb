# %% [markdown]
# Recipe Organizer

# %%
import pandas as pd
import os

# %%
columns = ["recipe_id",
           "name", 
           "ingredients", 
           "prep_time", 
           "instructions", 
           "difficulty", 
           "category", 
           "rating", 
           "times_cooked",
           "last_cooked"]

recipes = pd.DataFrame(columns = columns)
recipes
# Out:
# Empty DataFrame
# Columns: [recipe_id, name, ingredients, prep_time, instructions, difficulty, category, rating, times_cooked, last_cooked]
# Index: []

# %%
recipes.to_csv("./data/recipes.csv", mode = 'w', header = True, index = False)
print("File has been created!")
# Out:
# File has been created!

# %%
# %%writefile project_functions.py


"""
Recipe Manager Functions Module!!

This module contains the functions needed for our project
"""

# There should be more functions here, still not done.

def display_menu():
    """Display the main menu options."""
    print("\n=== Recipe Manager ===")
    print("1. Add a new recipe.")
    print("2. Search for recipe by ingredient.")
    print("3. View all recipes.")
    print("4. View a random recipes.")
    print("5. Exit")
    return input("Enter your choice (1-5): ")


def main():
    """
    This is the main application function. It displays the choices that direct the user to their needs.

    """

    print("Welcome to your all-incluive recipe tracker, Ctrl + Eat!")
    print("This app helps you add your favorite recipes and search through them. Ready to eat?")

    while True:
        choice = display_menu():
